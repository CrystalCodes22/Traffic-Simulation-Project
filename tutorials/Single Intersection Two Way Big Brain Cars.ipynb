# %% [markdown]
# # Tutorial 03: Running RLlib Experiments
#
# This tutorial walks you through the process of running traffic simulations in Flow with trainable RLlib-powered agents. Autonomous agents will learn to maximize a certain reward over the rollouts, using the [**RLlib**](https://ray.readthedocs.io/en/latest/rllib.html) library ([citation](https://arxiv.org/abs/1712.09381)) ([installation instructions](https://flow.readthedocs.io/en/latest/flow_setup.html#optional-install-ray-rllib)). Simulations of this form will depict the propensity of RL agents to influence the traffic of a human fleet in order to make the whole fleet more efficient (for some given metrics).
#
# In this tutorial, we simulate an initially perturbed single lane ring road, where we introduce a single autonomous vehicle. We witness that, after some training, that the autonomous vehicle learns to dissipate the formation and propagation of "phantom jams" which form when only human driver dynamics are involved.
#
# ## 1. Components of a Simulation
# All simulations, both in the presence and absence of RL, require two components: a *network*, and an *environment*. Networks describe the features of the transportation network used in simulation. This includes the positions and properties of nodes and edges constituting the lanes and junctions, as well as properties of the vehicles, traffic lights, inflows, etc... in the network. Environments, on the other hand, initialize, reset, and advance simulations, and act as the primary interface between the reinforcement learning algorithm and the network. Moreover, custom environments may be used to modify the dynamical features of an network. Finally, in the RL case, it is in the *environment* that the state/action spaces and the reward function are defined.
#
# ## 2. Setting up a Network
# Flow contains a plethora of pre-designed networks used to replicate highways, intersections, and merges in both closed and open settings. All these networks are located in flow/networks. For this tutorial, which involves a single lane ring road, we will use the network `RingNetwork`.
#
# ### 2.1 Setting up Network Parameters
#
# The network mentioned at the start of this section, as well as all other networks in Flow, are parameterized by the following arguments:
# * name
# * vehicles
# * net_params
# * initial_config
#
# These parameters are explained in detail in `tutorial01_sumo.ipynb`. Moreover, all parameters excluding vehicles (covered in section 2.2) do not change from the previous tutorial. Accordingly, we specify them nearly as we have before, and leave further explanations of the parameters to `tutorial01_sumo.ipynb`.
#
# We begin by choosing the network the experiment will be trained on. We use one of Flow's builtin networks, located in `flow.networks`. A list of all available networks can be found by running the script below.

# %%
import flow.networks as networks

print(networks.__all__)
# Out:
# using fixed init file======================================
# ['Network', 'BayBridgeNetwork', 'BayBridgeTollNetwork', 'BottleneckNetwork', 'FigureEightNetwork', 'TrafficLightGridNetwork', 'HighwayNetwork', 'RingNetwork', 'MergeNetwork', 'MultiRingNetwork', 'MiniCityNetwork', 'HighwayRampsNetwork', 'I210SubNetwork']

# %% [markdown]
# In this tutorial, we choose to use the ring road network. The network class is then:

# %% [markdown]
# One key difference between SUMO and RLlib experiments is that, in RLlib experiments, the network classes do not need to be defined; instead users should simply name the network class they wish to use. Later on, an environment setup module will import the correct network class based on the provided names.

# %%
ADDITIONAL_NET_PARAMS = {
    # radius of the circular components
    "radius_ring": 30,
    # number of lanes
    "lanes": 1,
    # speed limit for all edges
    "speed_limit": 3,
    # resolution of the curved portions
    "resolution": 40
}

# %%
from flow.networks import Network

class myNetwork(Network):  # update my network class

    def specify_nodes(self, net_params):
        # one of the elements net_params will need is a "radius" value
        r = 200 #net_params.additional_params["radius"]
        y = 20

        # specify the name and position (x,y) of each node
        nodes = [{"id": "center", "x": 0,  "y": 0},
                 {"id": "right", "x": r,  "y": 0},
                 {"id": "bottom", "x": 0,  "y": -r},
                 {"id": "left", "x": -r,  "y": 0},
                 {"id": "top", "x": 0,  "y": r}]
                 
            
            
            
            
            #{"id": "topright", "x": y,  "y": y},
                 #{"id": "bottomright",  "x": y,  "y": -y},
                 #{"id": "topleft",    "x": -y,  "y": y},
                 #{"id": "bottomleft",   "x": -y, "y": -y},
                 #{"id": "toprightright",   "x": r, "y": y},
                 #{"id": "bottomrightright",   "x": r, "y": -y},
                 #{"id": "topleftleft",   "x": -r, "y": y},
                 #{"id": "bottomleftleft",   "x": -r, "y": -y},
                 #{"id": "toptopright",   "x": y, "y": r},
                 #{"id": "toptopleft",   "x": -y, "y": r},
                 #{"id": "bottombottomright",   "x": y, "y": -r},
                 #{"id": "bottombottomleft",   "x": -y, "y": -r},]

        return nodes

# %%
# some mathematical operations that may be used
from numpy import pi, sin, cos, linspace

class myNetwork(myNetwork):  # update my network class

    def specify_edges(self, net_params):
        #r = 50 #net_params.additional_params["radius"]
        edgelen = 200#r * pi / 2
        # this will let us control the number of lanes in the network
        lanes = 3 #net_params.additional_params["num_lanes"]
        # speed limit of vehicles in the network
        speed_limit = net_params.additional_params["speed_limit"]

        edges = [
#             {
#                 "id": "edge0",
#                 "numLanes": lanes,
#                 "speed": speed_limit,
#                 "from": "bottomright",
#                 "to": "bottombottomright", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge1", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "topright", 
#                 "to": "bottomright", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge2", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "toptopright", 
#                 "to": "topright", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge3", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "bottombottomleft", 
#                 "to": "bottomleft", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge4",
#                 "numLanes": lanes,
#                 "speed": speed_limit,
#                 "from": "bottomleft",
#                 "to": "topleft", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge5", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "topleft", 
#                 "to": "toptopleft", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge6", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "toprightright", 
#                 "to": "topright", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge7", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "topright", 
#                 "to": "topleft", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge8", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "topleft", 
#                 "to": "topleftleft", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge9", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "bottomright", 
#                 "to": "bottomrightright", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge10", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "bottomleft", 
#                 "to": "bottomright", 
#                 "length": edgelen,
#             },
#             {
#                 "id": "edge11", 
#                 "numLanes": lanes, 
#                 "speed": speed_limit,
#                 "from": "bottomleftleft", 
#                 "to": "bottomleft", 
#                 "length": edgelen,
#             }
#            {
#                 "id": "edge0",
#                 "numLanes": lanes,
#                 "speed": speed_limit,
#                 "from": "bottomright",
#                 "to": "bottombottomright", 
#                 "length": edgelen,
#             },
            {
                "id": "edge1", 
                "numLanes": lanes, 
                "speed": speed_limit,
                "from": "center",
                "to": "right", 
                "length": edgelen,
            },
            {
                "id": "edge2", 
                "numLanes": lanes, 
                "speed": speed_limit,
                "from": "left",
                "to": "center",
                "length": edgelen,
            },
            {
                "id": "edge3", 
                "numLanes": lanes, 
                "speed": speed_limit,
                "from": "bottom",
                "to": "center",
                "length": edgelen,
            },
            {
                "id": "edge4",
                "numLanes": lanes,
                "speed": speed_limit,
                "from": "center",
                "to": "top", 
                "length": edgelen,
            },
            {
                "id": "edge1a",
                "numLanes": lanes, 
                "speed": speed_limit,
                "from": "right",
                "to": "center",
                "length": edgelen,
            },
            {
                "id": "edge2a",
                "numLanes": lanes, 
                "speed": speed_limit,
                "from": "center",
                "to": "left",
                "length": edgelen,
            },
            {
                "id": "edge3a", 
                "numLanes": lanes, 
                "speed": speed_limit,
                "from": "center",
                "to": "bottom",
                "length": edgelen,
            },
            {
                "id": "edge4a",
                "numLanes": lanes,
                "speed": speed_limit,
                "from": "top",
                "to": "center", 
                "length": edgelen,
            }
        ]

        return edges

# %%
from flow.networks import RingNetwork

# ring road network class
network_name = myNetwork

# %%
from flow.core.params import VehicleParams
import flow.controllers
from flow.controllers import IDMController, ContinuousRouter, RLController, routing_controllers
#from flow.controllers.routing_controllers import MinicityRouter
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams

vehicles = VehicleParams()
vehicles.add(veh_id="human",
             acceleration_controller=(RLController, {}),
             routing_controller=(flow.controllers.routing_controllers.MinicityRouter, {}),
             num_vehicles=6)

sim_params = SumoParams(sim_step=0.1, render=True, restart_instance=True)

initial_config = InitialConfig(bunching=1)

# %%
from flow.envs.ring.accel import AccelEnv, ADDITIONAL_ENV_PARAMS

env_params = EnvParams(additional_params=ADDITIONAL_ENV_PARAMS)

# %%
from flow.core.params import InFlows

inflow = InFlows()

inflow.add(veh_type="rl",
           edge="edge2",
           vehs_per_hour=4000,
           depart_lane="random")

inflow.add(veh_type="rl",
           edge="edge3",
           vehs_per_hour=4000,
           depart_lane="random")

inflow.add(veh_type="rl",
           edge="edge1a",
           vehs_per_hour=4000,
           depart_lane="random")

inflow.add(veh_type="rl",
           edge="edge4a",
           vehs_per_hour=4000,
           depart_lane="random")

additional_net_params = ADDITIONAL_NET_PARAMS.copy()
net_params = NetParams(inflows=inflow,  # our inflows
                       additional_params=additional_net_params)

# %%
# from flow.core.experiment import Experiment
# from flow.networks import FigureEightNetwork

# flow_params = dict(
#     exp_tag='test_network',
#     env_name=AccelEnv,
#     network=myNetwork,
#     simulator='traci',
#     sim=sim_params,
#     env=env_params,
#     net=net_params,
#     veh=vehicles,
#     initial=initial_config,
# )

# # number of time steps
# flow_params['env'].horizon = 10000
# exp = Experiment(flow_params)

# %%
# input parameter classes to the network class
from flow.core.params import NetParams, InitialConfig

# name of the network
name = "training_example"

# network-specific parameters
from flow.networks.ring import ADDITIONAL_NET_PARAMS
net_params = NetParams(additional_params=ADDITIONAL_NET_PARAMS)

# initial configuration to vehicles
initial_config = InitialConfig(spacing="uniform", perturbation=1)

# %% [markdown]
# ### 2.2 Adding Trainable Autonomous Vehicles
# The `Vehicles` class stores state information on all vehicles in the network. This class is used to identify the dynamical features of a vehicle and whether it is controlled by a reinforcement learning agent. Morover, information pertaining to the observations and reward function can be collected from various `get` methods within this class.
#
# The dynamics of vehicles in the `Vehicles` class can either be depicted by sumo or by the dynamical methods located in flow/controllers. For human-driven vehicles, we use the IDM model for acceleration behavior, with exogenous gaussian acceleration noise with std 0.2 m/s2 to induce perturbations that produce stop-and-go behavior. In addition, we use the `ContinousRouter` routing controller so that the vehicles may maintain their routes closed networks.
#
# As we have done in `tutorial01_sumo.ipynb`, human-driven vehicles are defined in the `VehicleParams` class as follows:

# %%
# # vehicles class
# from flow.core.params import VehicleParams

# # vehicles dynamics models
# from flow.controllers import IDMController, ContinuousRouter

# vehicles = VehicleParams()
# vehicles.add("human",
#              acceleration_controller=(IDMController, {}),
#              routing_controller=(ContinuousRouter, {}),
#              num_vehicles=21)

# %% [markdown]
# The above addition to the `Vehicles` class only accounts for 21 of the 22 vehicles that are placed in the network. We now add an additional trainable autuonomous vehicle whose actions are dictated by an RL agent. This is done by specifying an `RLController` as the acceleraton controller to the vehicle.

# %%
# from flow.controllers import RLController

# %% [markdown]
# Note that this controller serves primarirly as a placeholder that marks the vehicle as a component of the RL agent, meaning that lane changing and routing actions can also be specified by the RL agent to this vehicle.
#
# We finally add the vehicle as follows, while again using the `ContinuousRouter` to perpetually maintain the vehicle within the network.

# %%
# vehicles.add(veh_id="rl",
#              acceleration_controller=(RLController, {}),
#              routing_controller=(ContinuousRouter, {}),
#              num_vehicles=1)

# %% [markdown]
# ## 3. Setting up an Environment
#
# Several environments in Flow exist to train RL agents of different forms (e.g. autonomous vehicles, traffic lights) to perform a variety of different tasks. The use of an environment allows us to view the cumulative reward simulation rollouts receive, along with to specify the state/action spaces.
#
# Sumo envrionments in Flow are parametrized by three components:
# * `SumoParams`
# * `EnvParams`
# * `Network`
#
# ### 3.1 SumoParams
# `SumoParams` specifies simulation-specific variables. These variables include the length of any simulation step and whether to render the GUI when running the experiment. For this example, we consider a simulation step length of 0.1s and deactivate the GUI.
#
# **Note** For training purposes, it is highly recommanded to deactivate the GUI in order to avoid global slow down. In such case, one just needs to specify the following: `render=False`

# %%
from flow.core.params import SumoParams

sim_params = SumoParams(sim_step=0.1, render=False)

# %% [markdown]
# ### 3.2 EnvParams
#
# `EnvParams` specifies environment and experiment-specific parameters that either affect the training process or the dynamics of various components within the network. For the environment `WaveAttenuationPOEnv`, these parameters are used to dictate bounds on the accelerations of the autonomous vehicles, as well as the range of ring lengths (and accordingly network densities) the agent is trained on.
#
# Finally, it is important to specify here the *horizon* of the experiment, which is the duration of one episode (during which the RL-agent acquire data).

# %%
from flow.core.params import EnvParams

# Define horizon as a variable to ensure consistent use across notebook
HORIZON=100

env_params = EnvParams(
    # length of one rollout
    horizon=HORIZON,

    additional_params={
        # maximum acceleration of autonomous vehicles
        "max_accel": 1,
        # maximum deceleration of autonomous vehicles
        "max_decel": 1,
        # bounds on the ranges of ring road lengths the autonomous vehicle 
        # is trained on
        "ring_length": [220, 270],
    },
)

# %% [markdown]
# ### 3.3 Initializing a Gym Environment
#
# Now, we have to specify our Gym Environment and the algorithm that our RL agents will use. Similar to the network, we choose to use on of Flow's builtin environments, a list of which is provided by the script below.

# %%
import flow.envs as flowenvs

print(flowenvs.__all__)
# Out:
# ['Env', 'AccelEnv', 'LaneChangeAccelEnv', 'LaneChangeAccelPOEnv', 'TrafficLightGridTestEnv', 'MergePOEnv', 'BottleneckEnv', 'BottleneckAccelEnv', 'WaveAttenuationEnv', 'WaveAttenuationPOEnv', 'TrafficLightGridEnv', 'TrafficLightGridPOEnv', 'TrafficLightGridBenchmarkEnv', 'BottleneckDesiredVelocityEnv', 'TestEnv', 'BayBridgeEnv', 'BottleNeckAccelEnv', 'DesiredVelocityEnv', 'PO_TrafficLightGridEnv', 'GreenWaveTestEnv']

# %% [markdown]
# We will use the environment "WaveAttenuationPOEnv", which is used to train autonomous vehicles to attenuate the formation and propagation of waves in a partially observable variable density ring road. To create the Gym Environment, the only necessary parameters are the environment name plus the previously defined variables. These are defined as follows:

# %%
from flow.envs import WaveAttenuationPOEnv

env_name = WaveAttenuationPOEnv

# %% [markdown]
# ### 3.4 Setting up Flow Parameters
#
# RLlib experiments both generate a `params.json` file for each experiment run. For RLlib experiments, the parameters defining the Flow network and environment must be stored as well. As such, in this section we define the dictionary `flow_params`, which contains the variables required by the utility function `make_create_env`. `make_create_env` is a higher-order function which returns a function `create_env` that initializes a Gym environment corresponding to the Flow network specified.

# %%
# Creating flow_params. Make sure the dictionary keys are as specified. 
flow_params = dict(
    # name of the experiment
    exp_tag=name,
    # name of the flow environment the experiment is running on
    env_name=env_name,
    # name of the network class the experiment uses
    network=network_name,
    # simulator that is used by the experiment
    simulator='traci',
    # simulation-related parameters
    sim=sim_params,
    # environment related parameters (see flow.core.params.EnvParams)
    env=env_params,
    # network-related parameters (see flow.core.params.NetParams and
    # the network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,
    # vehicles to be placed in the network at the start of a rollout 
    # (see flow.core.vehicles.Vehicles)
    veh=vehicles,
    # (optional) parameters affecting the positioning of vehicles upon 
    # initialization/reset (see flow.core.params.InitialConfig)
    initial=initial_config
)

# %% [markdown]
# ## 4 Running RL experiments in Ray
#
# ### 4.1 Import
#
# First, we must import modules required to run experiments in Ray. The `json` package is required to store the Flow experiment parameters in the `params.json` file, as is `FlowParamsEncoder`. Ray-related imports are required: the PPO algorithm agent, `ray.tune`'s experiment runner, and environment helper methods `register_env` and `make_create_env`.

# %%
import json

import ray
try:
    from ray.rllib.agents.agent import get_agent_class
except ImportError:
    from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder

# %% [markdown]
# ### 4.2 Initializing Ray
# Here, we initialize Ray and experiment-based constant variables specifying parallelism in the experiment as well as experiment batch size in terms of number of rollouts.

# %%
# number of parallel workers
N_CPUS = 2
# number of rollouts per training iteration
N_ROLLOUTS = 1

ray.init(num_cpus=N_CPUS)
# Out:
# 2020-11-21 19:00:26,458	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-11-21 19:00:26,459	INFO resource_spec.py:216 -- Starting Ray with 14.11 GiB memory available for workers and up to 7.08 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# {'node_ip_address': '192.168.107.201',
#  'redis_address': '192.168.107.201:21237',
#  'object_store_address': '/tmp/ray/session_2020-11-21_19-00-26_457182_14895/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-11-21_19-00-26_457182_14895/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2020-11-21_19-00-26_457182_14895'}

# %% [markdown]
# ### 4.3 Configuration and Setup
# Here, we copy and modify the default configuration for the [PPO algorithm](https://arxiv.org/abs/1707.06347). The agent has the number of parallel workers specified, a batch size corresponding to `N_ROLLOUTS` rollouts (each of which has length `HORIZON` steps), a discount rate $\gamma$ of 0.999, two hidden layers of size 16, uses Generalized Advantage Estimation, $\lambda$ of 0.97, and other parameters as set below.
#
# Once `config` contains the desired parameters, a JSON string corresponding to the `flow_params` specified in section 3 is generated. The `FlowParamsEncoder` maps objects to string representations so that the experiment can be reproduced later. That string representation is stored within the `env_config` section of the `config` dictionary. Later, `config` is written out to the file `params.json`.
#
# Next, we call `make_create_env` and pass in the `flow_params` to return a function we can use to register our Flow environment with Gym.

# %%
# The algorithm or model to train. This may refer to "
#      "the name of a built-on algorithm (e.g. RLLib's DQN "
#      "or PPO), or a user-defined trainable function or "
#      "class registered in the tune registry.")
alg_run = "PPO"

agent_cls = get_agent_class(alg_run)
config = agent_cls._default_config.copy()
config["num_workers"] = N_CPUS - 1  # number of parallel workers
config["train_batch_size"] = HORIZON * N_ROLLOUTS  # batch size
config["gamma"] = 0.999  # discount rate
config["model"].update({"fcnet_hiddens": [16, 16]})  # size of hidden layers in network
config["use_gae"] = True  # using generalized advantage estimation
config["lambda"] = 0.97  
config["sgd_minibatch_size"] = min(16 * 1024, config["train_batch_size"])  # stochastic gradient descent
config["kl_target"] = 0.02  # target KL divergence
config["num_sgd_iter"] = 10  # number of SGD iterations
config["horizon"] = HORIZON  # rollout horizon

# save the flow params for replay
flow_json = json.dumps(flow_params, cls=FlowParamsEncoder, sort_keys=True,
                       indent=4)  # generating a string version of flow_params
config['env_config']['flow_params'] = flow_json  # adding the flow_params to config dict
config['env_config']['run'] = alg_run

# Call the utility function make_create_env to be able to 
# register the Flow env for this experiment
create_env, gym_name = make_create_env(params=flow_params, version=0)

# Register as rllib env with Gym
register_env(gym_name, create_env)

# %% [markdown]
# ### 4.4 Running Experiments
#
# Here, we use the `run_experiments` function from `ray.tune`. The function takes a dictionary with one key, a name corresponding to the experiment, and one value, itself a dictionary containing parameters for training.

# %%
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 1,  # number of iterations between checkpoints
        "checkpoint_at_end": True,  # generate a checkpoint at the end
        "max_failures": 999,
        "stop": {  # stopping conditions
            "training_iteration": 50,  # number of iterations to stop after
        },
    },
})
# Out:
# 2020-11-21 19:00:27,039	INFO ray_trial_executor.py:121 -- Trial PPO_WaveAttenuationPOEnv-v0_df57deda: Setting up new remote runner.
# == Status ==<br>Memory usage on this node: 3.6/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=15041) 2020-11-21 19:00:28,700	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=15041) using fixed init file======================================
# (pid=15041) 2020-11-21 19:00:29,048	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=15041) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15041) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15041) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15041) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15041) No routes specified, defaulting to single edge routes.
# (pid=15042) using fixed init file======================================
# (pid=15041) 2020-11-21 19:00:32,738	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 226
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 229
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 228
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-00-39
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -237.81833514315872
#   episode_reward_mean: -238.99967405798748
#   episode_reward_min: -240.1810129728162
#   episodes_this_iter: 2
#   episodes_total: 2
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 388.625
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.511974334716797
#         entropy_coeff: 0.0
#         kl: 3.1837821552471723e-06
#         policy_loss: -0.00040947197703644633
#         total_loss: 3259.291748046875
#         vf_explained_var: -1.138448715209961e-05
#         vf_loss: 3259.29248046875
#     load_time_ms: 70.567
#     num_steps_sampled: 200
#     num_steps_trained: 200
#     sample_time_ms: 5791.581
#     update_time_ms: 624.259
#   iterations_since_restore: 1
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 9.790909090909091
#     ram_util_percent: 13.645454545454545
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 9.73415967836902
#     mean_inference_ms: 1.0497819131879664
#     mean_processing_ms: 11.517849727649594
#   time_since_restore: 6.945937633514404
#   time_this_iter_s: 6.945937633514404
#   time_total_s: 6.945937633514404
#   timestamp: 1606014039
#   timesteps_since_restore: 200
#   timesteps_this_iter: 200
#   timesteps_total: 200
#   training_iteration: 1
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.2/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">     1</td><td style="text-align: right;">         6.94594</td><td style="text-align: right;">        200</td><td style="text-align: right;">    -239</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 230
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 236
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 264
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 239
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-00-46
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -237.81833514315872
#   episode_reward_mean: -240.9327145754089
#   episode_reward_min: -243.9976417320229
#   episodes_this_iter: 2
#   episodes_total: 6
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 170.318
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.05000000074505806
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.512762069702148
#         entropy_coeff: 0.0
#         kl: 2.7161836442246567e-06
#         policy_loss: -0.00038339942693710327
#         total_loss: 3352.3037109375
#         vf_explained_var: -2.4139881134033203e-05
#         vf_loss: 3352.303955078125
#     load_time_ms: 24.887
#     num_steps_sampled: 600
#     num_steps_trained: 600
#     sample_time_ms: 4070.758
#     update_time_ms: 210.615
#   iterations_since_restore: 3
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 7.0
#     ram_util_percent: 13.5
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 7.3969481693434895
#     mean_inference_ms: 0.9485733315803527
#     mean_processing_ms: 11.474724531924693
#   time_since_restore: 13.511649370193481
#   time_this_iter_s: 3.3367812633514404
#   time_total_s: 13.511649370193481
#   timestamp: 1606014046
#   timesteps_since_restore: 600
#   timesteps_this_iter: 200
#   timesteps_total: 600
#   training_iteration: 3
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.2/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">     3</td><td style="text-align: right;">         13.5116</td><td style="text-align: right;">        600</td><td style="text-align: right;">-240.933</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 232
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 220
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 265
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 250
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-00-53
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -237.81833514315872
#   episode_reward_mean: -243.4955803409451
#   episode_reward_min: -254.1941485701027
#   episodes_this_iter: 2
#   episodes_total: 10
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 129.291
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.012500000186264515
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.511015892028809
#         entropy_coeff: 0.0
#         kl: 3.6041437851963565e-06
#         policy_loss: -0.0006842073053121567
#         total_loss: 3371.3623046875
#         vf_explained_var: -2.849102020263672e-05
#         vf_loss: 3371.363037109375
#     load_time_ms: 15.653
#     num_steps_sampled: 1000
#     num_steps_trained: 1000
#     sample_time_ms: 3746.475
#     update_time_ms: 128.101
#   iterations_since_restore: 5
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 8.8
#     ram_util_percent: 13.5
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 6.505792567289703
#     mean_inference_ms: 0.9110306203224429
#     mean_processing_ms: 11.4655927172156
#   time_since_restore: 20.191253185272217
#   time_this_iter_s: 3.404451847076416
#   time_total_s: 20.191253185272217
#   timestamp: 1606014053
#   timesteps_since_restore: 1000
#   timesteps_this_iter: 200
#   timesteps_total: 1000
#   training_iteration: 5
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.2/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">     5</td><td style="text-align: right;">         20.1913</td><td style="text-align: right;">       1000</td><td style="text-align: right;">-243.496</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 267
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 253
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 241
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 233
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-00-59
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -237.81833514315872
#   episode_reward_mean: -244.40864054827392
#   episode_reward_min: -254.1941485701027
#   episodes_this_iter: 2
#   episodes_total: 14
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 110.753
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.0031250000465661287
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.509339332580566
#         entropy_coeff: 0.0
#         kl: 1.3479590279530385e-06
#         policy_loss: -0.00021965615451335907
#         total_loss: 3587.94287109375
#         vf_explained_var: -7.867813110351562e-06
#         vf_loss: 3587.943115234375
#     load_time_ms: 11.658
#     num_steps_sampled: 1400
#     num_steps_trained: 1400
#     sample_time_ms: 3627.384
#     update_time_ms: 92.825
#   iterations_since_restore: 7
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 7.260000000000001
#     ram_util_percent: 13.5
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 6.037969593798737
#     mean_inference_ms: 0.8962804464605171
#     mean_processing_ms: 11.46864521754954
#   time_since_restore: 27.00416088104248
#   time_this_iter_s: 3.399115562438965
#   time_total_s: 27.00416088104248
#   timestamp: 1606014059
#   timesteps_since_restore: 1400
#   timesteps_this_iter: 200
#   timesteps_total: 1400
#   training_iteration: 7
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.2/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">     7</td><td style="text-align: right;">         27.0042</td><td style="text-align: right;">       1400</td><td style="text-align: right;">-244.409</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 257
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 235
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 232
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 257
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-01-06
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -237.81833514315872
#   episode_reward_mean: -244.79715719690714
#   episode_reward_min: -254.1941485701027
#   episodes_this_iter: 2
#   episodes_total: 18
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 98.609
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.0007812500116415322
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.506628036499023
#         entropy_coeff: 0.0
#         kl: 4.450678716239054e-06
#         policy_loss: -0.0011934340000152588
#         total_loss: 3596.5224609375
#         vf_explained_var: 3.993511199951172e-06
#         vf_loss: 3596.5234375
#     load_time_ms: 9.452
#     num_steps_sampled: 1800
#     num_steps_trained: 1800
#     sample_time_ms: 3544.283
#     update_time_ms: 73.087
#   iterations_since_restore: 9
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 4.8
#     ram_util_percent: 13.419999999999998
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 5.738103153080863
#     mean_inference_ms: 0.887317993428442
#     mean_processing_ms: 11.470000190590545
#   time_since_restore: 33.645960569381714
#   time_this_iter_s: 3.2495553493499756
#   time_total_s: 33.645960569381714
#   timestamp: 1606014066
#   timesteps_since_restore: 1800
#   timesteps_this_iter: 200
#   timesteps_total: 1800
#   training_iteration: 9
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.2/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">     9</td><td style="text-align: right;">          33.646</td><td style="text-align: right;">       1800</td><td style="text-align: right;">-244.797</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 243
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 247
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 233
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 231
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-01-13
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -237.81833514315872
#   episode_reward_mean: -244.68061159161252
#   episode_reward_min: -254.1941485701027
#   episodes_this_iter: 2
#   episodes_total: 22
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 62.32
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.00019531250291038305
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.504024505615234
#         entropy_coeff: 0.0
#         kl: 3.425031991355354e-06
#         policy_loss: -0.0008406899869441986
#         total_loss: 3401.080078125
#         vf_explained_var: -0.00019985437393188477
#         vf_loss: 3401.0810546875
#     load_time_ms: 1.776
#     num_steps_sampled: 2200
#     num_steps_trained: 2200
#     sample_time_ms: 3255.86
#     update_time_ms: 4.167
#   iterations_since_restore: 11
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 5.3999999999999995
#     ram_util_percent: 13.4
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 5.51597453582824
#     mean_inference_ms: 0.8795974573066782
#     mean_processing_ms: 11.468702527019655
#   time_since_restore: 40.245492935180664
#   time_this_iter_s: 3.317063570022583
#   time_total_s: 40.245492935180664
#   timestamp: 1606014073
#   timesteps_since_restore: 2200
#   timesteps_this_iter: 200
#   timesteps_total: 2200
#   training_iteration: 11
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.2/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">    11</td><td style="text-align: right;">         40.2455</td><td style="text-align: right;">       2200</td><td style="text-align: right;">-244.681</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 222
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# ...
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 236
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-03-11
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -231.26883257599712
#   episode_reward_mean: -243.7410988694333
#   episode_reward_min: -256.881358482432
#   episodes_this_iter: 2
#   episodes_total: 94
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 59.147
#     learner:
#       default_policy:
#         cur_kl_coeff: 2.842170985392048e-15
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.473230361938477
#         entropy_coeff: 0.0
#         kl: 5.481690095621161e-06
#         policy_loss: -0.0006299465894699097
#         total_loss: 3388.153076171875
#         vf_explained_var: -0.00037997961044311523
#         vf_loss: 3388.15380859375
#     load_time_ms: 1.588
#     num_steps_sampled: 9400
#     num_steps_trained: 9400
#     sample_time_ms: 3087.549
#     update_time_ms: 4.227
#   iterations_since_restore: 47
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 5.35
#     ram_util_percent: 14.2
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 4.345090786862848
#     mean_inference_ms: 0.8187424136227329
#     mean_processing_ms: 11.449277772725463
#   time_since_restore: 156.5238320827484
#   time_this_iter_s: 3.07617449760437
#   time_total_s: 156.5238320827484
#   timestamp: 1606014191
#   timesteps_since_restore: 9400
#   timesteps_this_iter: 200
#   timesteps_total: 9400
#   training_iteration: 47
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.4/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">    47</td><td style="text-align: right;">         156.524</td><td style="text-align: right;">       9400</td><td style="text-align: right;">-243.741</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 225
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 265
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 254
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 243
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-03-17
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -231.26883257599712
#   episode_reward_mean: -243.96485233963713
#   episode_reward_min: -256.881358482432
#   episodes_this_iter: 2
#   episodes_total: 98
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 59.071
#     learner:
#       default_policy:
#         cur_kl_coeff: 7.10542746348012e-16
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.461450576782227
#         entropy_coeff: 0.0
#         kl: 6.183386176417116e-06
#         policy_loss: -0.0008701682090759277
#         total_loss: 3616.393310546875
#         vf_explained_var: -0.0020027756690979004
#         vf_loss: 3616.39404296875
#     load_time_ms: 1.567
#     num_steps_sampled: 9800
#     num_steps_trained: 9800
#     sample_time_ms: 3110.276
#     update_time_ms: 4.145
#   iterations_since_restore: 49
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 5.84
#     ram_util_percent: 14.040000000000001
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 4.3223760864896095
#     mean_inference_ms: 0.8171672876608853
#     mean_processing_ms: 11.44845171022689
#   time_since_restore: 163.10769820213318
#   time_this_iter_s: 3.271592617034912
#   time_total_s: 163.10769820213318
#   timestamp: 1606014197
#   timesteps_since_restore: 9800
#   timesteps_this_iter: 200
#   timesteps_total: 9800
#   training_iteration: 49
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.4/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc                  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>RUNNING </td><td>192.168.107.201:15041</td><td style="text-align: right;">    49</td><td style="text-align: right;">         163.108</td><td style="text-align: right;">       9800</td><td style="text-align: right;">-243.965</td></tr>
# </tbody>
# </table><br><br>
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 254
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# (pid=15042) /home/rrishi/flow/flow/envs/ring/wave_attenuation.py:45: RuntimeWarning: invalid value encountered in power
# (pid=15042)   error = s_eq_max - (s0 + v * tau) * (1 - (v / v0) ** gamma) ** -0.5
# (pid=15042) /home/rrishi/anaconda3/envs/flow/lib/python3.7/site-packages/scipy/optimize/minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
# (pid=15042)   improvement from the last ten iterations.
# (pid=15042)   warnings.warn(msg, RuntimeWarning)
# (pid=15042)
# (pid=15042) -----------------------
# (pid=15042) ring length: 242
# (pid=15042) v_max: 4.0
# (pid=15042) -----------------------
# (pid=15042) Warning: Speed of turning connection 'edge4a_0->edge2a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge1a_0->edge4_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge3_0->edge1_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) Warning: Speed of turning connection 'edge2_0->edge3a_0' reduced by 23.49 due to turning radius of 7.70 (length=9.03 angle=90.00)
# (pid=15042) No routes specified, defaulting to single edge routes.
# Result for PPO_WaveAttenuationPOEnv-v0_df57deda:
#   custom_metrics: {}
#   date: 2020-11-21_19-03-20
#   done: true
#   episode_len_mean: 100.0
#   episode_reward_max: -231.26883257599712
#   episode_reward_mean: -244.01423361369535
#   episode_reward_min: -256.881358482432
#   episodes_this_iter: 2
#   episodes_total: 100
#   experiment_id: b4c86df68499492abd1c33f2c04e892b
#   experiment_tag: '0'
#   hostname: Crystalcomp
#   info:
#     grad_time_ms: 59.499
#     learner:
#       default_policy:
#         cur_kl_coeff: 3.55271373174006e-16
#         cur_lr: 4.999999873689376e-05
#         entropy: 8.46782112121582
#         entropy_coeff: 0.0
#         kl: 8.767843610257842e-06
#         policy_loss: -0.0012448001652956009
#         total_loss: 3424.44140625
#         vf_explained_var: -0.0016742348670959473
#         vf_loss: 3424.44287109375
#     load_time_ms: 1.558
#     num_steps_sampled: 10000
#     num_steps_trained: 10000
#     sample_time_ms: 3125.536
#     update_time_ms: 3.959
#   iterations_since_restore: 50
#   node_ip: 192.168.107.201
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 6.175000000000001
#     ram_util_percent: 14.0
#   pid: 15041
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 4.3115568604660135
#     mean_inference_ms: 0.8164117347824329
#     mean_processing_ms: 11.44814281867889
#   time_since_restore: 166.35412669181824
#   time_this_iter_s: 3.2464284896850586
#   time_total_s: 166.35412669181824
#   timestamp: 1606014200
#   timesteps_since_restore: 10000
#   timesteps_this_iter: 200
#   timesteps_total: 10000
#   training_iteration: 50
#   trial_id: df57deda
# == Status ==<br>Memory usage on this node: 4.4/31.1 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/14.11 GiB heap, 0.0/4.88 GiB objects<br>Result logdir: /home/rrishi/ray_results/training_example<br>Number of trials: 1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status    </th><th>loc  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_df57deda</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    50</td><td style="text-align: right;">         166.354</td><td style="text-align: right;">      10000</td><td style="text-align: right;">-244.014</td></tr>
# </tbody>
# </table><br><br>

# %% [markdown]
# ### 4.5 Visualizing the results
#
# The simulation results are saved within the `ray_results/training_example` directory (we defined `training_example` at the start of this tutorial). The `ray_results` folder is by default located at your root `~/ray_results`.
#
# You can run `tensorboard --logdir=~/ray_results/training_example` (install it with `pip install tensorboard`) to visualize the different data outputted by your simulation.
#
# For more instructions about visualizing, please see `tutorial05_visualize.ipynb`.

# %% [markdown]
# ### 4.6 Restart from a checkpoint / Transfer learning
#
# If you wish to do transfer learning, or to resume a previous training, you will need to start the simulation from a previous checkpoint. To do that, you can add a `restore` parameter in the `run_experiments` argument, as follows:
#
# ```python
# trials = run_experiments({
#     flow_params["exp_tag"]: {
#         "run": alg_run,
#         "env": gym_name,
#         "config": {
#             **config
#         },
#         "restore": "/ray_results/experiment/dir/checkpoint_50/checkpoint-50"
#         "checkpoint_freq": 1,
#         "checkpoint_at_end": True,
#         "max_failures": 999,
#         "stop": {
#             "training_iteration": 1,
#         },
#     },
# })
# ```
#
# The `"restore"` path should be such that the `[restore]/.tune_metadata` file exists.
#
# There is also a `"resume"` parameter that you can set to `True` if you just wish to continue the training from a previously saved checkpoint, in case you are still training on the same experiment.
